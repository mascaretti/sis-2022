# %% [markdown]
# # Plots of MCMC

# %%
import arviz as az
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# ArviZ ships with style sheets!
az.style.use("arviz-darkgrid")

# %%
file_name = "/home/masca/Insync/andrea.mascaretti@studenti.unipd.it/Google Drive/phd/envelopes_files/mcmc-2022-02-27-08-19-02.pkl"
with (open(file_name, "rb")) as f:
    mcmc = pickle.load(f)

# %%
np.round(np.mean(mcmc.get("Beta"), axis=0), 3)
# Out:
# array([[1.8845e+01, 1.8736e+01],
#        [1.2000e-02, 1.2000e-02],
#        [1.0000e-03, 1.0000e-03]])

# %%
burn_in = 2000

# %%
mcmc.keys()
# Out:
# dict_keys(['mu', 'Gamma', 'Gamma_0', 'omega', 'omega_0', 'eta', 'Sigma', 'Beta'])

# %%
def print_beta(i: int, j: int, burn_in) -> None:
    assert i >= 0 and i <= 2, "Betas have three rows"
    assert j >= 0 and j <= 1, "Betas have two columns"
    az.plot_trace(mcmc.get("Beta")[burn_in:, i, j])

# %%
print_beta(2, 0, burn_in)

# %% [markdown]
# ## $\mu$

# %%
az.plot_trace(mcmc.get("mu")[burn_in:, 0])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("mu")[burn_in:, 1])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("mu")[burn_in:, 2])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
mcmc.get("omega")[burn_in:]

# %%
az.plot_trace(mcmc.get("omega")[burn_in:, 0])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("omega_0")[burn_in:, 0])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("omega_0")[burn_in:, 1])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("Sigma")[burn_in:, 0, 0])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
az.plot_trace(mcmc.get("eta")[burn_in:, 0, 0])
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'x'}>]], dtype=object)

# %%
np.mean(mcmc.get("Gamma")[burn_in:], axis=0)
# Out:
# array([[9.99983461e-01],
#        [7.13605886e-04],
#        [4.71097676e-05]])
